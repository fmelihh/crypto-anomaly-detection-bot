# %%
import requests

# %%
url = "https://api.binance.com/api/v3/ticker/price"

# %%
response = requests.get(url)

# %%
response.text
# Out:
# '[{"symbol":"ETHBTC","price":"0.06840000"},{"symbol":"LTCBTC","price":"0.00328400"},{"symbol":"BNBBTC","price":"0.01128100"},{"symbol":"NEOBTC","price":"0.00038950"},{"symbol":"QTUMETH","price":"0.00144600"},{"symbol":"EOSETH","price":"0.00047640"},{"symbol":"SNTETH","price":"0.00001264"},{"symbol":"BNTETH","price":"0.00021780"},{"symbol":"BCCBTC","price":"0.07908100"},{"symbol":"GASBTC","price":"0.00010480"},{"symbol":"BNBETH","price":"0.16500000"},{"symbol":"BTCUSDT","price":"27687.73000000"},{"symbol":"ETHUSDT","price":"1893.42000000"},{"symbol":"HSRBTC","price":"0.00041400"},{"symbol":"OAXETH","price":"0.00017780"},{"symbol":"DNTETH","price":"0.00002801"},{"symbol":"MCOETH","price":"0.00577200"},{"symbol":"ICNETH","price":"0.00166300"},{"symbol":"MCOBTC","price":"0.00021140"},{"symbol":"WTCBTC","price":"0.00000661"},{"symbol":"WTCETH","price":"0.00023700"},{"symbol":"LRCBTC","price":"0.00001052"},{"symbol":"LRCETH","price":"0.00015401"},{"symbol":"QTUMBTC","price":"0.00009930"},{
# ...
