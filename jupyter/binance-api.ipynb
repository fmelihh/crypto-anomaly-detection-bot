# %%
import requests

# %%
url = "https://api.binance.com/api/v3/ticker/price"

# %%
response = requests.get(url)

# %%
response.text
# Out:
# '[{"symbol":"ETHBTC","price":"0.06950000"},{"symbol":"LTCBTC","price":"0.00352500"},{"symbol":"BNBBTC","price":"0.01131800"},{"symbol":"NEOBTC","price":"0.00037890"},{"symbol":"QTUMETH","price":"0.00138400"},{"symbol":"EOSETH","price":"0.00047550"},{"symbol":"SNTETH","price":"0.00001244"},{"symbol":"BNTETH","price":"0.00022250"},{"symbol":"BCCBTC","price":"0.07908100"},{"symbol":"GASBTC","price":"0.00010220"},{"symbol":"BNBETH","price":"0.16280000"},{"symbol":"BTCUSDT","price":"26975.75000000"},{"symbol":"ETHUSDT","price":"1874.76000000"},{"symbol":"HSRBTC","price":"0.00041400"},{"symbol":"OAXETH","price":"0.00017780"},{"symbol":"DNTETH","price":"0.00002801"},{"symbol":"MCOETH","price":"0.00577200"},{"symbol":"ICNETH","price":"0.00166300"},{"symbol":"MCOBTC","price":"0.00021140"},{"symbol":"WTCBTC","price":"0.00000673"},{"symbol":"WTCETH","price":"0.00023700"},{"symbol":"LRCBTC","price":"0.00001012"},{"symbol":"LRCETH","price":"0.00014524"},{"symbol":"QTUMBTC","price":"0.00009600"},{
# ...

# %%
# every 5 second do request
